# %%
from typing import TypeDict,Dict
from langgraph.agent import StateGraph
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from typing import TypeDict,Dict
#       2 from langgraph.agent import StateGraph
#
# ImportError: cannot import name 'TypeDict' from 'typing' (C:\Users\FLH\miniconda4\Lib\typing.py)
